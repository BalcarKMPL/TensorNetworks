# %%
import numpy as np
from matplotlib import pyplot as plt
import Corelations

plt.rcParams['figure.figsize']=[16,9]
exponent = 1
dir = "./LOCAL_LR_BH_PEPS_0.02_1.0_1.96"
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [1], line 3
#       1 import numpy as np
#       2 from matplotlib import pyplot as plt
# ----> 3 import Corelations
#       5 plt.rcParams['figure.figsize']=[16,9]
#       6 exponent = 1
#
# File ~/PycharmProjects/TensorNetworks/Corelations.py:3
#       1 from ncon import ncon
#       2 import numpy as np
# ----> 3 import CTMRG
#       4 from time import time
#       6 def Corelation(env, PEPS, OL, OR, nmax):
#
# File ~/PycharmProjects/TensorNetworks/CTMRG.py:3
#       1 import numpy as np
#       2 from ncon import ncon
# ----> 3 from scipy.linalg import svd, norm, qr
#       4 from Tools import truncate3
#       5 from time import time
#
# ModuleNotFoundError: No module named 'scipy'

# %%
# Cor 0 exact
exact = dict(np.load(dir+"/EXACT_CORS.npz"))
E_AB_aah = exact['AB_aah_0']
E_BA_aah = exact['BA_aah_0']
E_AB_aha = exact['AB_aha_0']
E_BA_aha = exact['BA_aha_0']
ts = np.linspace(0,0.005*(len(E_BA_aah)-2),len(E_BA_aah), endpoint=True)

print(np.mean(E_AB_aha))
print(np.std(E_AB_aha))


plt.clf()
plt.title("A")
# plt.ylim(0.99999,1.00005)
plt.plot(ts,E_AB_aha.real, label='aha R')
plt.plot(ts,E_AB_aah.real, label='aah R')
plt.plot(ts,E_AB_aha.imag, label='aha I')
plt.plot(ts,E_AB_aah.imag, label='aah I')
plt.legend()
plt.show()
plt.clf()
plt.title("B")
# plt.ylim(0.99995,1.00001)
plt.plot(ts,E_BA_aha.real, label='aha R')
plt.plot(ts,E_BA_aah.real, label='aah R')
plt.plot(ts,E_BA_aha.imag, label='aha I')
plt.plot(ts,E_BA_aah.imag, label='aah I')
plt.legend()
plt.show()

plt.clf()
plt.title("SUM")
#plt.ylim(-0.000000000000000000001,0.000000000000000000001)
plt.plot(ts,E_AB_aha.real/2+E_AB_aah.real/2, label='aah+aha A REAL')
plt.plot(ts,E_BA_aha.real/2+E_BA_aah.real/2, label='aah+aha B REAL')
plt.plot(ts,E_AB_aha.imag/2+E_AB_aah.imag/2, label='aah+aha A IMAG')
plt.plot(ts,E_BA_aha.imag/2+E_BA_aah.imag/2, label='aah+aha B IMAG')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [2], in <cell line: 2>()
#       1 # Cor 0 exact
# ----> 2 exact = dict(np.load(dir+"/EXACT_CORS.npz"))
#       3 E_AB_aah = exact['AB_aah_0']
#       4 E_BA_aah = exact['BA_aah_0']
#
# File ~/Dokumenty/pythonProject1/venv/lib/python3.10/site-packages/numpy/lib/npyio.py:407, in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     405     own_fid = False
#     406 else:
# --> 407     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     408     own_fid = True
#     410 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: './LOCAL_LR_BH_PEPS_0.02_1.0_1.96/EXACT_CORS.npz'

# %%
# Cor 1 exact
exact = dict(np.load(dir+"/EXACT_CORS.npz"))
E_AB_aah = exact['AB_aah_1']
E_BA_aah = exact['BA_aah_1']
E_AB_aha = exact['AB_aha_1']
E_BA_aha = exact['BA_aha_1']

plt.clf()
plt.title("AB")
plt.plot(ts,E_AB_aha.real, label='aha R')
plt.plot(ts,E_AB_aah.real, label='aah R')
# plt.plot(ts,E_AB_aha.imag, label='aha I')
# plt.plot(ts,E_AB_aah.imag, label='aah I')
plt.legend()
plt.show()

plt.clf()
plt.title("BA")
plt.plot(ts,E_BA_aha.real, label='aha R')
plt.plot(ts,E_BA_aah.real, label='aah R')
# plt.plot(ts,E_BA_aha.imag, label='aha I')
# plt.plot(ts,E_BA_aah.imag, label='aah I')
plt.legend()
plt.show()

plt.clf()
plt.title("only REAL")
#plt.ylim(-0.000000000000000000001,0.000000000000000000001)
plt.plot(ts,E_AB_aha.real/2+E_AB_aah.real/2, label='aah+aha A REAL')
plt.plot(ts,E_AB_aha.real/2+E_AB_aah.real/2, label='aah+aha A REAL')
plt.plot(ts,E_BA_aha.real/2+E_BA_aah.real/2, label='aah+aha B REAL')
plt.plot(ts,E_BA_aha.real/2+E_BA_aah.real/2, label='aah+aha B REAL')
plt.legend()
plt.show()

plt.clf()
plt.title("only IMAG")
#plt.ylim(-0.000000000000000000001,0.000000000000000000001)
plt.plot(ts,E_AB_aha.imag/2+E_AB_aah.imag/2, label='aah+aha A IMAG')
plt.plot(ts,E_AB_aha.imag/2+E_AB_aah.imag/2, label='aah+aha A IMAG')
plt.plot(ts,E_BA_aha.imag/2+E_BA_aah.imag/2, label='aah+aha B IMAG')
plt.plot(ts,E_BA_aha.imag/2+E_BA_aah.imag/2, label='aah+aha B IMAG')
plt.legend()
plt.show()

# %%
# Cor 2 exact
exact = dict(np.load(dir+"/EXACT_CORS.npz"))
E_AB_aah = exact['AB_aah_2']
E_BA_aah = exact['BA_aah_2']
E_AB_aha = exact['AB_aha_2']
E_BA_aha = exact['BA_aha_2']

# plt.clf()
# plt.title("AB")
# # plt.plot(ts[:17],E_AB_aha.real[:17], label='aha R')
# # plt.plot(ts[:17],E_AB_aah.real[:17], label='aah R')
# plt.plot(ts,E_AB_aha.imag, label='aha I')
# plt.plot(ts,E_AB_aah.imag, label='aah I')
# plt.legend()
# plt.show()

plt.clf()
plt.title("AB")
# plt.xlim(0,0.5)
plt.plot(ts,E_AB_aha.real, label='aha R')
plt.plot(ts,E_AB_aah.real, label='aah R')
# plt.plot(ts,E_AB_aha.imag, label='aha I')
# plt.plot(ts,E_AB_aah.imag, label='aah I')
plt.legend()
plt.show()

plt.clf()
plt.title("BA")
plt.plot(ts,E_BA_aha.real, label='aha R')
plt.plot(ts,E_BA_aah.real, label='aah R')
# plt.plot(ts,E_BA_aha.imag, label='aha I')
# plt.plot(ts,E_BA_aah.imag, label='aah I')
plt.legend()
plt.show()

plt.clf()
plt.title("only REAL")
#plt.ylim(-0.000000000000000000001,0.000000000000000000001)
plt.plot(ts,E_AB_aha.real/2+E_AB_aah.real/2, label='aah+aha A REAL')
plt.plot(ts,E_AB_aha.real/2+E_AB_aah.real/2, label='aah+aha A REAL')
plt.plot(ts,E_BA_aha.real/2+E_BA_aah.real/2, label='aah+aha B REAL')
plt.plot(ts,E_BA_aha.real/2+E_BA_aah.real/2, label='aah+aha B REAL')
plt.legend()
plt.show()

plt.clf()
plt.title("only IMAG")
#plt.ylim(-0.000000000000000000001,0.000000000000000000001)
plt.plot(ts,E_AB_aha.imag/2+E_AB_aah.imag/2, label='aah+aha A IMAG')
plt.plot(ts,E_AB_aha.imag/2+E_AB_aah.imag/2, label='aah+aha A IMAG')
plt.plot(ts,E_BA_aha.imag/2+E_BA_aah.imag/2, label='aah+aha B IMAG')
plt.plot(ts,E_BA_aha.imag/2+E_BA_aah.imag/2, label='aah+aha B IMAG')
plt.legend()
plt.show()

# %%
dir = "./LOCAL_LR_BH_PEPS_0.02_1.0_1.96"

arA, arB = [], []
dist = 2

E_AB_aah = []
E_BA_aah = []
E_AB_aha = []
E_BA_aha = []

for i in range(1000):
    try:
        corrAAH = dict(np.load(dir+"/CORR_AAH_NS_{:05d}.npz".format(i)))
        corrAHA = dict(np.load(dir+"/CORR_AHA_NS_{:05d}.npz".format(i)))

        E_AB_aha.append(corrAHA['corA'][dist])
        E_AB_aah.append(corrAAH['corA'][dist])
        E_BA_aha.append(corrAHA['corB'][dist])
        E_BA_aah.append(corrAAH['corB'][dist])
    except:
        print(i)
        break

E_AB_aha = np.array(E_AB_aha)
E_AB_aah = np.array(E_AB_aah)
E_BA_aha = np.array(E_BA_aha)
E_BA_aah = np.array(E_BA_aah)
ts = np.linspace(0,10**(-exponent)*(len(E_BA_aah)-1),len(E_BA_aah), endpoint=True)

print(E_AB_aha)

plt.clf()
plt.title("AB")
plt.plot(ts,E_AB_aha.real, label='aha R')
plt.plot(ts,E_AB_aah.real, label='aah R')
# plt.plot(ts,E_AB_aha.imag, label='aha I')
# plt.plot(ts,E_AB_aah.imag, label='aah I')
plt.legend()
plt.show()

plt.clf()
plt.title("BA")
plt.plot(ts,E_BA_aha.real, label='aha R')
plt.plot(ts,E_BA_aah.real, label='aah R')
# plt.plot(ts,E_BA_aha.imag, label='aha I')
# plt.plot(ts,E_BA_aah.imag, label='aah I')
plt.legend()
plt.show()

plt.clf()
plt.title("only REAL")
#plt.ylim(-0.000000000000000000001,0.000000000000000000001)
plt.plot(ts,E_AB_aha.real/2+E_AB_aah.real/2, label='aah+aha A REAL')
plt.plot(ts,E_AB_aha.real/2+E_AB_aah.real/2, label='aah+aha A REAL')
plt.plot(ts,E_BA_aha.real/2+E_BA_aah.real/2, label='aah+aha B REAL')
plt.plot(ts,E_BA_aha.real/2+E_BA_aah.real/2, label='aah+aha B REAL')
plt.legend()
plt.show()

plt.clf()
plt.title("only IMAG")
#plt.ylim(-0.000000000000000000001,0.000000000000000000001)
plt.plot(ts,E_AB_aha.imag/2+E_AB_aah.imag/2, label='aah+aha A IMAG')
plt.plot(ts,E_AB_aha.imag/2+E_AB_aah.imag/2, label='aah+aha A IMAG')
plt.plot(ts,E_BA_aha.imag/2+E_BA_aah.imag/2, label='aah+aha B IMAG')
plt.plot(ts,E_BA_aha.imag/2+E_BA_aah.imag/2, label='aah+aha B IMAG')
plt.legend()
plt.show()
# Out:
# 17
# [0.00000000e+00+0.00000000e+00j 7.10911550e-08-3.09445239e-07j
#  7.09148486e-07-5.54086364e-07j 3.18369308e-06-8.54061076e-07j
#  9.81434502e-06-1.15205193e-06j 2.37121617e-05-1.45017871e-06j
#  4.88185439e-05-1.74528135e-06j 8.98058797e-05-2.04387809e-06j
#  1.51898539e-04-2.32608793e-06j 2.41275200e-04-2.65300093e-06j
#  3.64401212e-04-2.99435602e-06j 5.28265520e-04-3.26287236e-06j
#  7.39908123e-04-3.54985740e-06j 1.00711890e-03-4.02762283e-06j
#  1.33792959e-03-4.42992224e-06j 1.73964542e-03-4.86438055e-06j
#  2.21960166e-03-5.26839368e-06j]
